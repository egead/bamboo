# %% [markdown]
# # Time Lag Correlation

# %%
import pandas as pd
import numpy as np
import corrfuncs as cf

# %%
df = pd.read_csv('/home/ege/Desktop/project/new/Concat_DFs/20220420_CONCAT_DF.csv',index_col=0)

# %%
x= df.values
df = pd.DataFrame(x[:,1:].T,columns=df.index,index=df.columns.values[1:])

# %%
len(df.columns)
# Out:
# 77

# %%
df2=df.shift(periods=-1).fillna(0)
df2
# Out:
#      SSE_600200  SSE_600370  SSE_600740  SSE_600733  SSE_600725  SSE_600521  \
# 1      0.002154    0.010333   -0.029221    0.003244    0.000312    0.046176
# 2      0.002957    0.005867    0.000014   -0.005348    0.050583    0.021671
# 3     -0.007755   -0.001138   -0.015170   -0.009995   -0.011202    0.045769
# 4      0.004269    0.005937   -0.045702    0.021983   -0.002151   -0.005807
# 5     -0.004792    0.000526    0.013973   -0.003406    0.007085   -0.006636
# ..          ...         ...         ...         ...         ...         ...
# 230    0.010858    0.005981   -0.004211    0.004358    0.003620   -0.005759
# 231    0.012968   -0.004231   -0.001077    0.004735    0.006272    0.008947
# 232   -0.011120    0.000897    0.002951    0.003374   -0.004485   -0.008578
# 233   -0.006575    0.003576   -0.014847   -0.003202   -0.000180   -0.010047
# 234    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
#
# ...

# %%
df.corrwith(df2)
# Out:
# SSE_600200    0.419550
# SSE_600370   -0.186527
# SSE_600740    0.117056
# SSE_600733    0.294712
# SSE_600725    0.073694
#                 ...
# SSE_600522    0.330638
# SSE_600628    0.120477
# SSE_600219    0.095415
# SSE_600686    0.131785
# SSE_600569    0.197323
# Length: 77, dtype: float64

# %%
cf.timelagcorrM(df,lag=-1)
# Out:
# 77
# nan
# /home/ege/anaconda3/envs/earth-ml/lib/python3.10/site-packages/numpy/lib/function_base.py:2829: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# (     SSE_600200  SSE_600370  SSE_600740  SSE_600733  SSE_600725  SSE_600521  \
#  1     -0.018381    0.003545    0.063349    0.000694    0.043591   -0.054268
#  2      0.002154    0.010333   -0.029221    0.003244    0.000312    0.046176
#  3      0.002957    0.005867    0.000014   -0.005348    0.050583    0.021671
#  4     -0.007755   -0.001138   -0.015170   -0.009995   -0.011202    0.045769
#  5      0.004269    0.005937   -0.045702    0.021983   -0.002151   -0.005807
#  ..          ...         ...         ...         ...         ...         ...
#  230    0.025805   -0.000824    0.001318    0.004474    0.003197    0.015629
#  231    0.010858    0.005981   -0.004211    0.004358    0.003620   -0.005759
#  232    0.012968   -0.004231   -0.001077    0.004735    0.006272    0.008947
# ...

# %%
cf.timelagcorrM(df,lag=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 cf.timelagcorrM(df,lag=1)
#
# File ~/Desktop/project/new/corrfuncs.py:78, in timelagcorrM(df1, lag)
#      76 for i in range(len(df1.columns)):
#      77     for j in range(len(df1.columns)):
# ---> 78         data.append(np.corrcoef(df1.iloc[i].df2.iloc[j])[0,1])
#      79 print(len(df1.columns))
#      80 dataArr = np.array(data)
#
# File ~/anaconda3/envs/earth-ml/lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# ...

# %%
234*234
# Out:
# 54756

# %%
def timelagcorr(df1,i,j,lag=0):
    """ Computes Lag-N correlation coefficent of two values in a dataframe. 
    
    Parameters
    ----------
    df1 : pandas.Dataframe
    lag : int, default 0
    i,j : int, Used for indexing the dataframe
    
    Returns
    ----------
    np.corrcoef: float
    """
    df1.replace(np.nan,0,inplace=True)
    df2 = df1.shift(lag)
    df2.replace(np.nan,0,inplace=True)   
    #X[i,j]=np.corrcoef(veci,vecj)
    return df2#np.corrcoef(df1.iloc[i].values,df2.iloc[j].values)[0,1]

# %%
timelagcorr(df,0,1,lag=1)
# Out:
#               0         1         2         3         4         5         6  \
# SSE_600200  0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SSE_600370  0.0 -0.018381  0.002154  0.002957 -0.007755  0.004269 -0.004792
# SSE_600740  0.0  0.003545  0.010333  0.005867 -0.001138  0.005937  0.000526
# SSE_600733  0.0  0.063349 -0.029221  0.000014 -0.015170 -0.045702  0.013973
# SSE_600725  0.0  0.000694  0.003244 -0.005348 -0.009995  0.021983 -0.003406
# ...         ...       ...       ...       ...       ...       ...       ...
# SSE_600522  0.0  0.004747  0.003602  0.001448 -0.004470 -0.001716 -0.004884
# SSE_600628  0.0 -0.004942 -0.019908 -0.028816 -0.058124 -0.004688  0.048855
# SSE_600219  0.0 -0.009594  0.035645  0.021788  0.007276 -0.013719 -0.017613
# SSE_600686  0.0 -0.002957  0.000769 -0.000776 -0.013042 -0.008750  0.004940
# SSE_600569  0.0  0.018029  0.002678  0.018703  0.029298  0.024978 -0.004146
#
# ...

# %%
df.shift(periods=-1).fillna(0).reset_index()
# Out:
#          index    0         1         2         3         4         5  \
# 0   SSE_600200  0.0  0.003545  0.010333  0.005867 -0.001138  0.005937
# 1   SSE_600370  0.0  0.063349 -0.029221  0.000014 -0.015170 -0.045702
# 2   SSE_600740  0.0  0.000694  0.003244 -0.005348 -0.009995  0.021983
# 3   SSE_600733  0.0  0.043591  0.000312  0.050583 -0.011202 -0.002151
# 4   SSE_600725  0.0 -0.054268  0.046176  0.021671  0.045769 -0.005807
# ..         ...  ...       ...       ...       ...       ...       ...
# 72  SSE_600522  0.0 -0.009594  0.035645  0.021788  0.007276 -0.013719
# 73  SSE_600628  0.0 -0.002957  0.000769 -0.000776 -0.013042 -0.008750
# 74  SSE_600219  0.0  0.018029  0.002678  0.018703  0.029298  0.024978
# 75  SSE_600686  0.0  0.006027  0.008930  0.006012 -0.013285 -0.026795
# 76  SSE_600569  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
#
#            6         7         8  ...       225       226       227       228  \
# ...

# %%
df
# Out:
#               0         1         2         3         4         5         6  \
# SSE_600200  0.0 -0.018381  0.002154  0.002957 -0.007755  0.004269 -0.004792
# SSE_600370  0.0  0.003545  0.010333  0.005867 -0.001138  0.005937  0.000526
# SSE_600740  0.0  0.063349 -0.029221  0.000014 -0.015170 -0.045702  0.013973
# SSE_600733  0.0  0.000694  0.003244 -0.005348 -0.009995  0.021983 -0.003406
# SSE_600725  0.0  0.043591  0.000312  0.050583 -0.011202 -0.002151  0.007085
# ...         ...       ...       ...       ...       ...       ...       ...
# SSE_600522  0.0 -0.004942 -0.019908 -0.028816 -0.058124 -0.004688  0.048855
# SSE_600628  0.0 -0.009594  0.035645  0.021788  0.007276 -0.013719 -0.017613
# SSE_600219  0.0 -0.002957  0.000769 -0.000776 -0.013042 -0.008750  0.004940
# SSE_600686  0.0  0.018029  0.002678  0.018703  0.029298  0.024978 -0.004146
# SSE_600569  0.0  0.006027  0.008930  0.006012 -0.013285 -0.026795 -0.011239
#
# ...
